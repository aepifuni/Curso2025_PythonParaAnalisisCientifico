# %% [markdown]
# # Pandas

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# # Pandas Series
#
#
# *   s.count() : Devuelve el número de elementos que no son nulos ni NaN en la serie s.
# *   s.sum() : Devuelve la suma de los datos de la serie s cuando los datos son de un tipo numérico, o la concatenación de ellos cuando son del tipo cadena str.
#
#
# *   s.cumsum() : Devuelve una serie con la suma acumulada de los datos de la serie s cuando los datos son de un tipo numérico.
# *   s.value_counts() : Devuelve una serie con la frecuencia (número de repeticiones) de cada valor de la serie s.
#
# *   s.min() : Devuelve el menor de los datos de la serie s.
# *   s.max() : Devuelve el mayor de los datos de la serie s.
#
#
# *   s.mean() : Devuelve la media de los datos de la serie s cuando los datos son de un tipo numérico.
# *   s.var() : Devuelve la varianza de los datos de la serie s cuando los datos son de un tipo numérico.
#
#
#
# *   s.std() : Devuelve la desviación típica de los datos de la serie s cuando los datos son de un tipo numérico.
# *   s.describe(): Devuelve una serie con un resumen descriptivo que incluye el número de datos, su suma, el mínimo, el máximo, la media, la desviación típica y los cuartiles.

# %% [markdown]
# Series es un objeto unidimensional (1D) similar a la columna de una tabla. Si queremos crear un Series para un listado de nombres, podemos hacer lo siguiente:

# %%
labels = ['a','b','c']
my_list = [10,20,30]
arr = np.array([10,20,30])
d = {'a':10,'b':20,'c':30}

# %%
pd.Series(data=my_list)
# Out:
# 0    10
# 1    20
# 2    30
# dtype: int64

# %%
pd.Series(data=my_list, index=labels)
# Out:
# a    10
# b    20
# c    30
# dtype: int64

# %%
pd.Series(data=arr)
# Out:
# 0    10
# 1    20
# 2    30
# dtype: int64

# %%
pd.Series(data=d)
# Out:
# a    10
# b    20
# c    30
# dtype: int64

# %% [markdown]
# # Pandas DataFrame

# %% [markdown]
# El DataFrame es una estructura de datos tabular que se compone de columnas y filas ordenadas.
#
#
# *   df.info() : Devuelve información (número de filas, número de columnas, índices, tipo de las columnas y memoria usado) sobre el DataFrame df.
#
# *   df.shape : Devuelve una tupla con el número de filas y columnas del DataFrame df.
# *   df.size : Devuelve el número de elementos del DataFrame.
#
#
# *   df.columns : Devuelve una lista con los nombres de las columnas del DataFrame df.
# *   df.index : Devuelve una lista con los nombres de las filas del DataFrame df.
#
#
# *   df.dtypes : Devuelve una serie con los tipos de datos de las columnas del DataFrame df.
# *   df.head(n) : Devuelve las n primeras filas del DataFrame df.
#
#
#
#
# *   df.tail(n) : Devuelve las n últimas filas del DataFrame df.

# %%
import numpy as np
from numpy.random import randn

# %%
df = pd.DataFrame(randn(5,4),index='A B C D E'.split(),columns='W X Y Z'.split())

# %%
df
# Out:
#           W         X         Y         Z
# A -1.636998  0.224623 -0.038357 -1.383101
# B -0.292760  0.603806 -1.102275 -1.637422
# C -1.724824 -1.000369 -0.624820  0.534790
# D -0.743437  0.359326 -0.268837 -0.002699
# E  2.106972  0.091064  1.594052  1.089684

# %%
df = pd.DataFrame(randn(5,4),columns='W X Y Z'.split())

# %%
df
# Out:
#           W         X         Y         Z
# 0  1.534023  1.289263  0.717844  0.393098
# 1 -1.999721  0.715635  1.123295 -1.176308
# 2  1.734841  0.241099 -0.589429 -0.173981
# 3  0.451482  1.826222 -1.758823 -2.131689
# 4 -0.645250  0.946523  0.181722  0.437138

# %%
df['W']
# Out:
# 0    1.534023
# 1   -1.999721
# 2    1.734841
# 3    0.451482
# 4   -0.645250
# Name: W, dtype: float64

# %%
df[['W']]
# Out:
#           W
# 0  1.534023
# 1 -1.999721
# 2  1.734841
# 3  0.451482
# 4 -0.645250

# %%
df[['W', 'Y']]
# Out:
#           W         Y
# 0  1.534023  0.717844
# 1 -1.999721  1.123295
# 2  1.734841 -0.589429
# 3  0.451482 -1.758823
# 4 -0.645250  0.181722

# %%
df
# Out:
#           W         X         Y         Z
# 0  1.534023  1.289263  0.717844  0.393098
# 1 -1.999721  0.715635  1.123295 -1.176308
# 2  1.734841  0.241099 -0.589429 -0.173981
# 3  0.451482  1.826222 -1.758823 -2.131689
# 4 -0.645250  0.946523  0.181722  0.437138

# %%
df['new'] = df['W'] + df['Y']-df['Z']

# %%
df
# Out:
#           W         X         Y         Z       new
# 0  1.534023  1.289263  0.717844  0.393098  1.858769
# 1 -1.999721  0.715635  1.123295 -1.176308  0.299882
# 2  1.734841  0.241099 -0.589429 -0.173981  1.319393
# 3  0.451482  1.826222 -1.758823 -2.131689  0.824348
# 4 -0.645250  0.946523  0.181722  0.437138 -0.900666

# %% [markdown]
# ## Drop

# %%
df.drop('new', axis=1)
# Out:
#           W         X         Y         Z
# 0  1.534023  1.289263  0.717844  0.393098
# 1 -1.999721  0.715635  1.123295 -1.176308
# 2  1.734841  0.241099 -0.589429 -0.173981
# 3  0.451482  1.826222 -1.758823 -2.131689
# 4 -0.645250  0.946523  0.181722  0.437138

# %%
df
# Out:
#           W         X         Y         Z
# 0  1.534023  1.289263  0.717844  0.393098
# 1 -1.999721  0.715635  1.123295 -1.176308
# 2  1.734841  0.241099 -0.589429 -0.173981
# 3  0.451482  1.826222 -1.758823 -2.131689
# 4 -0.645250  0.946523  0.181722  0.437138

# %%
df1 = df.drop('new', axis=1)
# axis = 0     filas
# axis = 1     columnas
df1
# Out:
#           W         X         Y         Z
# 0  1.534023  1.289263  0.717844  0.393098
# 1 -1.999721  0.715635  1.123295 -1.176308
# 2  1.734841  0.241099 -0.589429 -0.173981
# 3  0.451482  1.826222 -1.758823 -2.131689
# 4 -0.645250  0.946523  0.181722  0.437138

# %%
df.drop('new', axis=1, inplace=True)

# %%
df
# Out:
#           W         X         Y         Z
# A -0.232530  1.224328  0.945037 -1.036474
# B  0.498837 -0.378086  0.296622 -1.270095
# C -0.807219 -1.292753  1.771960 -0.105584
# D -0.112157 -0.776375  1.416146 -0.605529
# E -0.863059 -0.700690 -1.407069 -0.777064

# %%
df.loc['B']
# Out:
# W    0.498837
# X   -0.378086
# Y    0.296622
# Z   -1.270095
# Name: B, dtype: float64

# %%
df.iloc[0]
# Out:
# W   -0.232530
# X    1.224328
# Y    0.945037
# Z   -1.036474
# Name: A, dtype: float64

# %%
df
# Out:
#           W         X         Y         Z
# A -0.232530  1.224328  0.945037 -1.036474
# B  0.498837 -0.378086  0.296622 -1.270095
# C -0.807219 -1.292753  1.771960 -0.105584
# D -0.112157 -0.776375  1.416146 -0.605529
# E -0.863059 -0.700690 -1.407069 -0.777064

# %%
df>0
# Out:
#        W      X      Y      Z
# A  False   True   True  False
# B   True  False   True  False
# C  False  False   True  False
# D  False  False   True  False
# E  False  False  False  False

# %%
df[df>0]
# Out:
#           W         X         Y   Z
# A       NaN  1.224328  0.945037 NaN
# B  0.498837       NaN  0.296622 NaN
# C       NaN       NaN  1.771960 NaN
# D       NaN       NaN  1.416146 NaN
# E       NaN       NaN       NaN NaN

# %%
df2 = df[df>0]
df2
# Out:
#           W         X         Y   Z
# A       NaN  1.224328  0.945037 NaN
# B  0.498837       NaN  0.296622 NaN
# C       NaN       NaN  1.771960 NaN
# D       NaN       NaN  1.416146 NaN
# E       NaN       NaN       NaN NaN

# %%
df[df['W']>0]
# Out:
#           W         X         Y         Z
# B  0.498837 -0.378086  0.296622 -1.270095

# %%
df[df['Y']>0]['X']
# Out:
# A    1.224328
# B   -0.378086
# C   -1.292753
# D   -0.776375
# Name: X, dtype: float64

# %%
df[ (df['Y']>0) & (df['Y']<1) ] [['W','X']]
# Out:
#           W         X
# A -0.232530  1.224328
# B  0.498837 -0.378086

# %% [markdown]
# # Missing data

# %%
df = pd.DataFrame({'A':[1,2,np.nan],
                  'B':[5,np.nan,np.nan],
                  'C':[1,2,3]})

# %%
df
# Out:
#      A    B  C
# 0  1.0  5.0  1
# 1  2.0  NaN  2
# 2  NaN  NaN  3

# %%
df.dropna()
# Out:
#      A    B  C
# 0  1.0  5.0  1

# %%
df.dropna(axis=1)
# Out:
#    C
# 0  1
# 1  2
# 2  3

# %%
df.dropna(axis=1, inplace=True)

# %%
df
# Out:
#    C
# 0  1
# 1  2
# 2  3

# %%
df = pd.DataFrame({'A':[1,2,np.nan],
                  'B':[5,np.nan,np.nan],
                  'C':[1,2,3]})
df
# Out:
#      A    B  C
# 0  1.0  5.0  1
# 1  2.0  NaN  2
# 2  NaN  NaN  3

# %%
df.fillna(value='val')
# Out:
#      A    B  C
# 0  1.0  5.0  1
# 1  2.0  val  2
# 2  val  val  3

# %%
df['A'].fillna(value=df['A'].mean(), inplace=True)
# Out:
# <ipython-input-216-f52828da4a8e>:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['A'].fillna(value=df['A'].mean(), inplace=True)

# %%
df
# Out:
#      A    B  C
# 0  1.0  5.0  1
# 1  2.0  NaN  2
# 2  1.5  NaN  3

# %% [markdown]
# # Groupby

# %%
data = {'Company':['GOOG','GOOG','MSFT','MSFT','FB','FB'],
       'Person':['Sam','Charlie','Amy','Vanessa','Carl','Sarah'],
       'Sales':[200,120,340,124,243,350]}

# %%
df = pd.DataFrame(data)

# %%
df
# Out:
#   Company   Person  Sales
# 0    GOOG      Sam    200
# 1    GOOG  Charlie    120
# 2    MSFT      Amy    340
# 3    MSFT  Vanessa    124
# 4      FB     Carl    243
# 5      FB    Sarah    350

# %%
df.groupby('Company')

# %%
gb = df.groupby('Company')
print(df.dtypes)
# Out:
# Company    object
# Person     object
# Sales       int64
# dtype: object

# %%
gb['Sales'].mean()
# Out:
# Company
# FB      296.5
# GOOG    160.0
# MSFT    232.0
# Name: Sales, dtype: float64

# %%
gb['Sales'].std()
# Out:
# Company
# FB       75.660426
# GOOG     56.568542
# MSFT    152.735065
# Name: Sales, dtype: float64

# %%
gb.max()
# Out:
#           Person  Sales
# Company
# FB         Sarah    350
# GOOG         Sam    200
# MSFT     Vanessa    340

# %%
gb.count()
# Out:
#          Person  Sales
# Company
# FB            2      2
# GOOG          2      2
# MSFT          2      2

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6 entries, 0 to 5
# Data columns (total 3 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Company  6 non-null      object
#  1   Person   6 non-null      object
#  2   Sales    6 non-null      int64
# dtypes: int64(1), object(2)
# memory usage: 276.0+ bytes

# %%
df.describe()
# Out:
#             Sales
# count    6.000000
# mean   229.500000
# std    100.899455
# min    120.000000
# 25%    143.000000
# 50%    221.500000
# 75%    315.750000
# max    350.000000

# %%
gb.describe()
# Out:
#         Sales
#         count   mean         std    min     25%    50%     75%    max
# Company
# FB        2.0  296.5   75.660426  243.0  269.75  296.5  323.25  350.0
# GOOG      2.0  160.0   56.568542  120.0  140.00  160.0  180.00  200.0
# MSFT      2.0  232.0  152.735065  124.0  178.00  232.0  286.00  340.0

# %%
gb.describe().transpose()
# Out:
# Company              FB        GOOG        MSFT
# Sales count    2.000000    2.000000    2.000000
#       mean   296.500000  160.000000  232.000000
#       std     75.660426   56.568542  152.735065
#       min    243.000000  120.000000  124.000000
#       25%    269.750000  140.000000  178.000000
#       50%    296.500000  160.000000  232.000000
#       75%    323.250000  180.000000  286.000000
#       max    350.000000  200.000000  340.000000

# %%
gb.describe().transpose()[['FB']]
# Out:
# Company              FB
# Sales count    2.000000
#       mean   296.500000
#       std     75.660426
#       min    243.000000
#       25%    269.750000
#       50%    296.500000
#       75%    323.250000
#       max    350.000000

# %% [markdown]
# # Concatenating

# %%
df1 = pd.DataFrame({'A': ['A0', 'A1', 'A2', 'A3'],
                        'B': ['B0', 'B1', 'B2', 'B3'],
                        'C': ['C0', 'C1', 'C2', 'C3'],
                        'D': ['D0', 'D1', 'D2', 'D3']},
                        index=[0, 1, 2, 3])

df1
# Out:
#     A   B   C   D
# 0  A0  B0  C0  D0
# 1  A1  B1  C1  D1
# 2  A2  B2  C2  D2
# 3  A3  B3  C3  D3

# %%
df2 = pd.DataFrame({'A': ['A4', 'A5', 'A6', 'A7'],
                        'B': ['B4', 'B5', 'B6', 'B7'],
                        'C': ['C4', 'C5', 'C6', 'C7'],
                        'D': ['D4', 'D5', 'D6', 'D7']},
                         index=[4, 5, 6, 7])

df2
# Out:
#     A   B   C   D
# 4  A4  B4  C4  D4
# 5  A5  B5  C5  D5
# 6  A6  B6  C6  D6
# 7  A7  B7  C7  D7

# %%
df3 = pd.DataFrame({'A': ['A8', 'A9', 'A10', 'A11'],
                        'B': ['B8', 'B9', 'B10', 'B11'],
                        'C': ['C8', 'C9', 'C10', 'C11'],
                        'D': ['D8', 'D9', 'D10', 'D11'],},
                        index=[8, 9, 10, 11])

df3
# Out:
#       A    B    C    D
# 8    A8   B8   C8   D8
# 9    A9   B9   C9   D9
# 10  A10  B10  C10  D10
# 11  A11  B11  C11  D11

# %%
pd.concat([df1,df3,df2])
# Out:
#       A    B    C    D
# 0    A0   B0   C0   D0
# 1    A1   B1   C1   D1
# 2    A2   B2   C2   D2
# 3    A3   B3   C3   D3
# 8    A8   B8   C8   D8
# 9    A9   B9   C9   D9
# 10  A10  B10  C10  D10
# 11  A11  B11  C11  D11
# 4    A4   B4   C4   D4
# 5    A5   B5   C5   D5
# 6    A6   B6   C6   D6
# 7    A7   B7   C7   D7

# %%
pd.concat([df1,df2,df3])
# Out:
#       A    B    C    D
# 0    A0   B0   C0   D0
# 1    A1   B1   C1   D1
# 2    A2   B2   C2   D2
# 3    A3   B3   C3   D3
# 4    A4   B4   C4   D4
# 5    A5   B5   C5   D5
# 6    A6   B6   C6   D6
# 7    A7   B7   C7   D7
# 8    A8   B8   C8   D8
# 9    A9   B9   C9   D9
# 10  A10  B10  C10  D10
# 11  A11  B11  C11  D11

# %%
dfc = pd.concat([df2,df3,df1])
dfc
# Out:
#       A    B    C    D
# 4    A4   B4   C4   D4
# 5    A5   B5   C5   D5
# 6    A6   B6   C6   D6
# 7    A7   B7   C7   D7
# 8    A8   B8   C8   D8
# 9    A9   B9   C9   D9
# 10  A10  B10  C10  D10
# 11  A11  B11  C11  D11
# 0    A0   B0   C0   D0
# 1    A1   B1   C1   D1
# 2    A2   B2   C2   D2
# 3    A3   B3   C3   D3

# %%
dfc.reset_index(drop=True, inplace=True)

# %%
dfc
# Out:
#       A    B    C    D
# 0    A4   B4   C4   D4
# 1    A5   B5   C5   D5
# 2    A6   B6   C6   D6
# 3    A7   B7   C7   D7
# 4    A8   B8   C8   D8
# 5    A9   B9   C9   D9
# 6   A10  B10  C10  D10
# 7   A11  B11  C11  D11
# 8    A0   B0   C0   D0
# 9    A1   B1   C1   D1
# 10   A2   B2   C2   D2
# 11   A3   B3   C3   D3

# %%
pd.concat([df1,df2,df3], axis=1)
# Out:
#       A    B    C    D    A    B    C    D    A    B    C    D
# 0    A0   B0   C0   D0  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 1    A1   B1   C1   D1  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 2    A2   B2   C2   D2  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 3    A3   B3   C3   D3  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 4   NaN  NaN  NaN  NaN   A4   B4   C4   D4  NaN  NaN  NaN  NaN
# 5   NaN  NaN  NaN  NaN   A5   B5   C5   D5  NaN  NaN  NaN  NaN
# 6   NaN  NaN  NaN  NaN   A6   B6   C6   D6  NaN  NaN  NaN  NaN
# 7   NaN  NaN  NaN  NaN   A7   B7   C7   D7  NaN  NaN  NaN  NaN
# 8   NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN   A8   B8   C8   D8
# 9   NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN   A9   B9   C9   D9
# 10  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  A10  B10  C10  D10
# 11  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  A11  B11  C11  D11

# %% [markdown]
# # Operaciones

# %%
df = pd.DataFrame({'col1':[1,2,3,4],'col2':[444,555,666,444],'col3':['abc','def','ghi','xyz']})

# %%
df
# Out:
#    col1  col2 col3
# 0     1   444  abc
# 1     2   555  def
# 2     3   666  ghi
# 3     4   444  xyz

# %%
df.head(2)
# Out:
#    col1  col2 col3
# 0     1   444  abc
# 1     2   555  def

# %%
df.tail(2)
# Out:
#    col1  col2 col3
# 2     3   666  ghi
# 3     4   444  xyz

# %%
df['col2'].unique()
# Out:
# array([444, 555, 666])

# %%
df['col2'].value_counts()
# Out:
# col2
# 444    2
# 555    1
# 666    1
# Name: count, dtype: int64

# %%
df.sort_values(by='col2')
# Out:
#    col1  col2 col3
# 0     1   444  abc
# 3     4   444  xyz
# 1     2   555  def
# 2     3   666  ghi

# %%
df.isnull()
# Out:
#     col1   col2   col3
# 0  False  False  False
# 1  False  False  False
# 2  False  False  False
# 3  False  False  False

# %%
data = {'A':['foo','foo','foo','bar','bar','bar'],
     'B':['one','one','two','two','one','one'],
       'C':['x','y','x','y','x','y'],
       'D':[1,3,2,5,4,1]}

df = pd.DataFrame(data)

# %%
df
# Out:
#      A    B  C  D
# 0  foo  one  x  1
# 1  foo  one  y  3
# 2  foo  two  x  2
# 3  bar  two  y  5
# 4  bar  one  x  4
# 5  bar  one  y  1

# %%
df.pivot_table(values='D', index=['A','B'], columns=['C'])
# Out:
# C          x    y
# A   B
# bar one  4.0  1.0
#     two  NaN  5.0
# foo one  1.0  3.0
#     two  2.0  NaN

# %% [markdown]
# # Data input and output

# %%
df = pd.read_csv('Inventory_v2.csv')

# %%
df
# Out:
#     product.partNumber location.locationIdentifier inventoryType  quantity  \
# 0           PS-SL-A287                        LT-1       PRODUCT        25
# 1           PS-SL-A288                        LT-1       PRODUCT        20
# 2           PS-SL-H309                        LT-1       PRODUCT         3
# 3           PS-SL-H310                        LT-1       PRODUCT        35
# 4           PS-SL-F342                        LT-1       PRODUCT        43
# ..                 ...                         ...           ...       ...
# 149           83600200                        LT-2          ITEM       118
# 150           83600300                        LT-2          ITEM       323
# 151            9664145                        LT-2          ITEM       273
# 152            9664146                        LT-2          ITEM       259
# 153            9664147                        LT-2          ITEM        27
#
#     quantityUnits     value valueCurrency  reservationOrders  daysOfSupply  \
# 0              EA   31250.0           USD                  2            19
# 1              EA   25000.0           USD                  2            35
# 2              EA    3750.0           USD                  2            14
# 3              EA   43750.0           USD                  2            16
# 4              EA   53750.0           USD                  2            42
# ..            ...       ...           ...                ...           ...
# 149            EA  151866.0           USD                  0            41
# 150            EA  470288.0           USD                  0            44
# 151            EA  227409.0           USD                  0            27
# 152            EA  267288.0           USD                  0            42
# 153            EA   26352.0           USD                  0            56
#
#      shelfLife  ...  quantityUpperThreshold  quantityLowerThreshold  \
# 0          365  ...                     100                      10
# 1          365  ...                     100                      10
# 2          365  ...                     100                      10
# 3          365  ...                     100                      10
# 4          365  ...                     100                      10
# ..         ...  ...                     ...                     ...
# 149        365  ...                     400                     100
# 150        365  ...                     400                     100
# 151        365  ...                     400                     100
# 152        365  ...                     400                     100
# 153        365  ...                     400                     100
#
#      daysOfSupplyUpperThreshold  daysOfSupplyLowerThreshold  \
# 0                            30                          10
# 1                            30                          10
# 2                            30                          10
# 3                            30                          10
# 4                            30                          10
# ..                          ...                         ...
# 149                          30                          10
# 150                          30                          10
# 151                          30                          10
# 152                          30                          10
# 153                          30                          10
#
#      expiringThreshold         plannerCode  velocityCode inventoryParentType  \
# 0                  NaN     Street Lighting             B              ONHAND
# 1                  NaN     Street Lighting             B              ONHAND
# 2                  NaN     Street Lighting             B              ONHAND
# 3                  NaN     Street Lighting             A              ONHAND
# 4                  NaN     Street Lighting             A              ONHAND
# ..                 ...                 ...           ...                 ...
# 149                NaN  Primary Foundation            C               ONHAND
# 150                NaN  Primary Foundation            C               ONHAND
# 151                NaN   Secondary Chassis            C               ONHAND
# 152                NaN   Secondary Chassis            A               ONHAND
# 153                NaN   Secondary Chassis            A               ONHAND
#
#     class     segment
# 0     NEW  INDUSTRIAL
# 1     NEW  INDUSTRIAL
# 2     NEW  INDUSTRIAL
# 3     NEW  INDUSTRIAL
# 4     NEW  INDUSTRIAL
# ..    ...         ...
# 149   NEW         NaN
# 150   NEW         NaN
# 151   NEW         NaN
# 152   NEW         NaN
# 153   NEW         NaN
#
# [154 rows x 22 columns]

# %%
df.to_csv('example_salida.csv')
